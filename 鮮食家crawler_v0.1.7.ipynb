# %%
import requests as rq
from bs4 import BeautifulSoup as bs
from collections import OrderedDict as od
from threading import Thread
from queuelib import queue
from datetime import datetime
import time
import random
import json
import csv
import traceback as tb
import re

# %%
HOST = 'https://www.famicloud.com.tw'

# %%
index_url = HOST

# %% [markdown]
# # 上層爬蟲

# %%
def famicloud_crawler():
    res_index = rq.get(index_url)
    soup_index = bs(res_index.text, 'lxml')
    soup_li = soup_index.li
    
    
    for i in range (1 ,1000):
        try:
            small_branch = soup_li.select('a')[i].text
            pre_small_branch_url = soup_li.select('a')[i]['href']
            small_branch_url = "{}{}".format(index_url, pre_small_branch_url)
            
            print(small_branch_url)
            #交給中層爬蟲
            pass

        except KeyError:       
            sub_branch = soup_li.select('a')[i].text
            #print(sub_branch)

        except IndexError:
            break   

    print("[INFO] famicloud_crawler complete!")

# %%
famicloud_crawler()
# Out:
# https://www.famicloud.com.tw/Branchs/Branch/Index/1/563/564
# https://www.famicloud.com.tw/Branchs/Branch/Index/1/287/288
# https://www.famicloud.com.tw/Branchs/Branch/Index/1/908/914
# https://www.famicloud.com.tw/Branchs/Branch/Index/1/565/566
# https://www.famicloud.com.tw/Branchs/Branch/Index/312/313/316
# https://www.famicloud.com.tw/Branchs/Branch/Index/312/895/896
# https://www.famicloud.com.tw/Branchs/Branch/Index/312/895/897
# https://www.famicloud.com.tw/Branchs/Branch/Index/312/356/357
# https://www.famicloud.com.tw/Branchs/Branch/Index/312/356/358
# https://www.famicloud.com.tw/Branchs/Branch/Index/312/548/549
# https://www.famicloud.com.tw/Branchs/Branch/Index/312/607/608
# https://www.famicloud.com.tw/Branchs/Branch/Index/312/504/505
# https://www.famicloud.com.tw/Branchs/Branch/Index/312/504/506
# https://www.famicloud.com.tw/Branchs/Branch/Index/312/504/507
# https://www.famicloud.com.tw/Branchs/Branch/Index/312/504/508
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/9/27
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/9/28
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/9/29
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/9/30
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/9/31
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/9/32
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/9/33
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/9/34
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/9/35
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/9/36
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/9/104
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/9/208
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/9/469
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/9/470
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/9/491
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/9/929
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/10/37
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/10/38
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/10/39
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/10/40
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/10/42
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/10/192
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/11/46
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/11/47
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/11/468
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/11/1033
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/12/49
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/105/110
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/105/466
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/105/579
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/105/631
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/105/749
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/105/762
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/105/774
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/105/930
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/105/931
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/105/1021
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/105/1032
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/105/1062
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/105/1102
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/105/1123
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/105/1161
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/105/1165
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/105/1218
# https://www.famicloud.com.tw/Branchs/Branch/Index/2/105/1253
# https://www.famicloud.com.tw/Branchs/Branch/Index/622/633/635
# https://www.famicloud.com.tw/Branchs/Branch/Index/622/745/746
# https://www.famicloud.com.tw/Branchs/Branch/Index/622/745/755
# https://www.famicloud.com.tw/Branchs/Branch/Index/622/745/756
# https://www.famicloud.com.tw/Branchs/Branch/Index/622/745/757
# https://www.famicloud.com.tw/Branchs/Branch/Index/622/745/758
# https://www.famicloud.com.tw/Branchs/Branch/Index/622/844/845
# https://www.famicloud.com.tw/Branchs/Branch/Index/622/634/638
# https://www.famicloud.com.tw/Branchs/Branch/Index/622/639/640
# https://www.famicloud.com.tw/Branchs/Branch/Index/622/641/642
# https://www.famicloud.com.tw/Branchs/Branch/Index/622/763/764
# https://www.famicloud.com.tw/Branchs/Branch/Index/622/772/773
# https://www.famicloud.com.tw/Branchs/Branch/Index/622/772/786
# https://www.famicloud.com.tw/Branchs/Branch/Index/622/1005/1006
# https://www.famicloud.com.tw/Branchs/Branch/Index/622/1278/1279
# https://www.famicloud.com.tw/Branchs/Branch/Index/622/623/629
# https://www.famicloud.com.tw/Branchs/Branch/Index/3/13/50
# https://www.famicloud.com.tw/Branchs/Branch/Index/3/13/51
# https://www.famicloud.com.tw/Branchs/Branch/Index/3/13/52
# https://www.famicloud.com.tw/Branchs/Branch/Index/3/13/53
# https://www.famicloud.com.tw/Branchs/Branch/Index/3/14/55
# https://www.famicloud.com.tw/Branchs/Branch/Index/3/14/56
# https://www.famicloud.com.tw/Branchs/Branch/Index/3/14/57
# https://www.famicloud.com.tw/Branchs/Branch/Index/3/14/58
# https://www.famicloud.com.tw/Branchs/Branch/Index/3/14/59
# https://www.famicloud.com.tw/Branchs/Branch/Index/3/14/246
# https://www.famicloud.com.tw/Branchs/Branch/Index/3/14/247
# https://www.famicloud.com.tw/Branchs/Branch/Index/3/14/248
# https://www.famicloud.com.tw/Branchs/Branch/Index/3/209/210
# https://www.famicloud.com.tw/Branchs/Branch/Index/3/129/179
# https://www.famicloud.com.tw/Branchs/Branch/Index/3/129/181
# https://www.famicloud.com.tw/Branchs/Branch/Index/3/129/182
# https://www.famicloud.com.tw/Branchs/Branch/Index/3/106/114
# https://www.famicloud.com.tw/Branchs/Branch/Index/3/106/185
# https://www.famicloud.com.tw/Branchs/Branch/Index/3/106/216
# https://www.famicloud.com.tw/Branchs/Branch/Index/3/106/245
# https://www.famicloud.com.tw/Branchs/Branch/Index/3/106/443
# https://www.famicloud.com.tw/Branchs/Branch/Index/3/106/632
# https://www.famicloud.com.tw/Branchs/Branch/Index/3/106/748
# https://www.famicloud.com.tw/Branchs/Branch/Index/3/106/843
# https://www.famicloud.com.tw/Branchs/Branch/Index/3/106/1164
# https://www.famicloud.com.tw/Branchs/Branch/Index/3/106/1179
# https://www.famicloud.com.tw/Branchs/Branch/Index/3/106/1239
# https://www.famicloud.com.tw/Branchs/Branch/Index/3/106/1273
# https://www.famicloud.com.tw/Branchs/Branch/Index/4/133/134
# https://www.famicloud.com.tw/Branchs/Branch/Index/4/133/510
# https://www.famicloud.com.tw/Branchs/Branch/Index/4/133/511
# https://www.famicloud.com.tw/Branchs/Branch/Index/4/133/512
# https://www.famicloud.com.tw/Branchs/Branch/Index/4/303/304
# https://www.famicloud.com.tw/Branchs/Branch/Index/4/303/887
# https://www.famicloud.com.tw/Branchs/Branch/Index/4/303/1192
# https://www.famicloud.com.tw/Branchs/Branch/Index/4
# https://www.famicloud.com.tw/Branchs/Branch/Index/254/257/1274
# https://www.famicloud.com.tw/Branchs/Branch/Index/254/257/1281
# https://www.famicloud.com.tw/Branchs/Branch/Index/254/257/1282
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/881/884
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/881/885
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/881/886
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/881/1159
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/881/1160
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/880/882
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/880/883
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/880/1168
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/880/1169
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/1016/1017
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/910
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/911
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/912
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/913
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/917
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/918
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/919
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/928
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/936
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1001
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1015
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1041
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1046
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1065
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1073
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1076
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1091
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1100
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1101
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1121
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1122
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1124
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1125
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1127
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1128
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1129
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1130
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1131
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1133
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1135
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1137
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1138
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1139
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1140
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1142
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1143
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1144
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1145
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1146
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1147
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1148
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1149
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1150
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1151
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1152
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1153
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1154
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1155
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1156
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1157
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1227
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1249
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1268
# https://www.famicloud.com.tw/Branchs/Branch/Index/879/909/1280
# https://www.famicloud.com.tw/Branchs/Branch/Index/948/949/950
# https://www.famicloud.com.tw/Branchs/Branch/Index/948/951/952
# https://www.famicloud.com.tw/Branchs/Branch/Index/948/951/953
# https://www.famicloud.com.tw/Branchs/Branch/Index/948/951/1184
# https://www.famicloud.com.tw/Branchs/Branch/Index/948/951/1185
# https://www.famicloud.com.tw/Branchs/Branch/Index/948/951/1203
# https://www.famicloud.com.tw/Branchs/Branch/Index/948/954/955
# https://www.famicloud.com.tw/Branchs/Branch/Index/948/965/966
# https://www.famicloud.com.tw/Branchs/Branch/Index/948/958/959
# https://www.famicloud.com.tw/Branchs/Branch/Index/948/958/960
# https://www.famicloud.com.tw/Branchs/Branch/Index/948/958/1172
# https://www.famicloud.com.tw/Branchs/Branch/Index/948/958/1173
# https://www.famicloud.com.tw/Branchs/Branch/Index/948/961/962
# https://www.famicloud.com.tw/Branchs/Branch/Index/948/961/963
# https://www.famicloud.com.tw/Branchs/Branch/Index/948/961/964
# https://www.famicloud.com.tw/Branchs/Branch/Index/948/961/1170
# https://www.famicloud.com.tw/Branchs/Branch/Index/948/961/1171
# https://www.famicloud.com.tw/Branchs/Branch/Index/948/967/968
# https://www.famicloud.com.tw/Branchs/Branch/Index/948/967/1052
# https://www.famicloud.com.tw/Branchs/Branch/Index/948/956/957
# https://www.famicloud.com.tw/Branchs/Branch/Index/948/1018/1019
# https://www.famicloud.com.tw/Branchs/Branch/Index/948/1026/1027
# https://www.famicloud.com.tw/Branchs/Branch/Index/948/1026/1081
# https://www.famicloud.com.tw/Branchs/Branch/Index/948/1026/1186
# https://www.famicloud.com.tw/Branchs/Branch/Index/948/1082/1083
# https://www.famicloud.com.tw/Branchs/Branch/Index/948/1082/1085
# https://www.famicloud.com.tw/Branchs/Branch/Index/948/1082/1086
# [INFO] famicloud_crawler complete!

# %% [markdown]
# # 中層爬蟲

# %%
from selenium import webdriver

# %%
test_url = "https://www.famicloud.com.tw/Branchs/Branch/Index/5/272/1271"

# %%
test_url2 = 'https://www.famicloud.com.tw/Branchs/Branch/Index/312/548/549'

# %%
# 擷取 JavaScript 渲染的網頁原始碼，先指定 PhantomJs 安裝位置
driver = webdriver.PhantomJS(executable_path='C:/Users/nick800608/phantomjs-2.1.1-windows/bin/phantomjs')

# %%
driver.get(test_url2)    # 輸入範例網址，交給瀏覽器

# %%
pageSource = driver.page_source    # 取得網頁原始碼 (含 JavaScript)

# %%
# print(pageSource)
soup = bs(pageSource, 'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class=" js flexbox flexboxlegacy canvas canvastext no-webgl touch no-geolocation postmessage websqldatabase indexeddb hashchange history draganddrop websockets rgba hsla multiplebgs backgroundsize borderimage borderradius boxshadow textshadow opacity cssanimations csscolumns cssgradients cssreflections csstransforms csstransforms3d csstransitions fontface generatedcontent no-video no-audio localstorage sessionstorage webworkers applicationcache svg inlinesvg smil svgclippaths"><head><style type="text/css">@charset "UTF-8";[ng\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide:not(.ng-hide-animate){display:none !important;}ng\:form{display:block;}.ng-animate-shim{visibility:hidden;}.ng-anchor{position:absolute;}</style>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0" name="viewport"/>
# <meta content="中祥" name="Keywords"/>
# <meta content="" name="description"/>
# <meta content="中祥-鮮食家雲端冰箱" property="og:title"/>
# <meta content="product" property="og:type"/>
# <meta content="鮮食家" property="og:site_name"/>
# <meta content="" property="og:description"/>
# <meta content="https://www.famicloud.com.tw/Branchs/Branch/Index/5/272/1271" property="og:url"/>
# <meta content="" property="og:image"/>
# <!-- 網站管理員start -->
# <meta content="UnXkZYoiOa299Vnh7RI25qy0xfST7TUSVjvc4xfIoKc" name="google-site-verification"/>
# <meta content="A1D102D3D706A26DA752F9CC3F267D35" name="msvalidate.01"/>
# <meta content="1wasvkd1kls3tsipwjqp228ha6kkzvho74ww864r5sx16x58ae0iqpzu7-v327w26elzw0zfcqo2s7k2kv1ziovmafn8e8cj2n5phy3p7y1pso1it-cbdcw0u87ai4n-" name="norton-safeweb-site-verification"/>
# <!-- 網站管理員end -->
# <title>中祥-鮮食家雲端冰箱</title>
# <link href="/img/famicloud.ico" rel="SHORTCUT ICON"/>
# </head><body><iframe src="https://img.scupio.com/html/ls.html?mid=240" style="display: none; position: absolute; visibility: hidden;"></iframe><iframe height="1" scrolling="no" src="//ad.tagtoo.co/static/ad/html/track.html#ad=408&amp;p=https%3A%2F%2Fwww.famicloud.com.tw%2FBranchs%2FBranch%2FIndex%2F5%2F272%2F1271" style="display: none;" width="1"></iframe><script async="" src="//bat.bing.com/bat.js"></script><script async="" src="https://s.yimg.com/wi/ytc.js"></script><script async="" src="//www.googletagmanager.com/gtm.js?id=GTM-K796GD&amp;l=TagtoodataLayer"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script async="" src="//cdn.tagtoo.com.tw/ec/js/ec.js" type="text/javascript"></script><script async="" src="//cdn.tagtoo.com.tw/gtm/js/jquery.js" type="text/javascript"></script><script async="" src="//cdn.tagtoo.com.tw/gtm/js/track2.js" type="text/javascript"></script><script async="" src="//cdn.tagtoo.com.tw/gtm/js/tagtoosdk.js" type="text/javascript"></script><script async="" src="//www.googletagmanager.com/gtm.js?id=GTM-PZD8XX&amp;l=TagtoodataLayer"></script><script src="https://rec.scupio.com/recweb/rec.aspx?mid=240&amp;pid=cat3_m&amp;ch=1271&amp;rcat=null&amp;uid=&amp;vidx=0&amp;v=1.16.5&amp;fp=c1488552683984xaaf21b26e&amp;gt=&amp;u=https%3A%2F%2Fwww.famicloud.com.tw%2FBranchs%2FBranch%2FIndex%2F5%2F272%2F1271&amp;r=&amp;vt=1488552683252_6610"></script><script async="" src="https://s.yimg.com/wi/ytc.js"></script><script async="" src="https://d31qbv1cthcecs.cloudfront.net/atrk.js" type="text/javascript"></script><script async="" src="//www.google-analytics.com/analytics.js"></script><script src="//bw.scupio.com/Conv/Conversion.aspx?callback=Scupioads.conv.send&amp;ProjectID=894&amp;pid=action&amp;gid=0&amp;uu=https%3A%2F%2Fwww.famicloud.com.tw%2FBranchs%2FBranch%2FIndex%2F5%2F272%2F1271&amp;ts=0.706101538380608"></script><script src="https://img.scupio.com/js/jquery.min.js"></script><script src="https://ajax.googleapis.com/ajax/libs/jquery/1.7.2/jquery.min.js"></script><script async="" src="//ad.tagtoo.co/media/ad/track.js" type="text/javascript"></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script async="" src="//d17m68fovwmgxj.cloudfront.net/js/rt/track.js"></script><script type="text/javascript">
#             var appInsights = window.appInsights || function (config) {
#                 function r(config) { t[config] = function () { var i = arguments; t.queue.push(function () { t[config].apply(t, i) }) } } var t = { config: config }, u = document, e = window, o = "script", s = u.createElement(o), i, f; for (s.src = config.url || "//az416426.vo.msecnd.net/scripts/a/ai.0.js", u.getElementsByTagName(o)[0].parentNode.appendChild(s), t.cookie = u.cookie, t.queue = [], i = ["Event", "Exception", "Metric", "PageView", "Trace"]; i.length;) r("track" + i.pop()); return r("setAuthenticatedUserContext"), r("clearAuthenticatedUserContext"), config.disableExceptionTracking || (i = "onerror", r("_" + i), f = e[i], e[i] = function (config, r, u, e, o) { var s = f && f(config, r, u, e, o); return s !== !0 && t["_" + i](config, r, u, e, o), s }), t
#             }({
#                 instrumentationKey: "552d1e8e-cc99-4c70-bf50-2ca0e27ec1b5"
#             });
#
#             window.appInsights = appInsights;
#             appInsights.trackPageView();
#         </script><script src="//az416426.vo.msecnd.net/scripts/a/ai.0.js"></script>
# <link href="/Content/reset.css" rel="stylesheet"/>
# <link href="/Content/basic.css?20161201" rel="stylesheet"/>
# <link href="/Content/mb01.css" rel="stylesheet"/>
# <link href="/Content/mb02.css" rel="stylesheet"/>
# <link href="/Content/banner.css" rel="stylesheet"/>
# <link href="/Content/font-awesome.min.css" rel="stylesheet"/>
# <!-- Bootstrap  -->
# <link href="/assets/css/bootstrap.min.css" rel="stylesheet"/>
# <!-- icon fonts font Awesome -->
# <link href="/assets/css/font-awesome.min.css" rel="stylesheet"/>
# <!-- Import Magnific Pop Up Styles -->
# <link href="/assets/css/magnific-popup.css" rel="stylesheet"/>
# <!-- Import Custom Styles -->
# <link href="/assets/css/style.css" rel="stylesheet"/>
# <link href="/Content/layout.css" rel="stylesheet"/>
# <link href="/Content/footer.css" rel="stylesheet"/>
# <link href="/jqueryui/jquery-ui.min.css" rel="stylesheet"/>
# <script src="/Scripts/jquery-2.1.4.min.js"></script>
# <script src="/js/info-slide.js"></script>
# <script src="/Scripts/jquery.cookie.js"></script>
# <script type="text/javascript">
#         $(function () {
#             // 預設顯示第一個 Tab
#             var _showTab = 0;
#             var $defaultLi = $('ul.tabs2 li').eq(_showTab).addClass('active2');
#             $($defaultLi.find('a').attr('href')).siblings().hide();
#
#             // 當 li 頁籤被點擊時...
#             // 若要改成滑鼠移到 li 頁籤就切換時, 把 click 改成 mouseover
#             $('ul.tabs2 li').click(function () {
#                 // 找出 li 中的超連結 href(#id)
#                 var $this = $(this),
#                     _clickTab = $this.find('a').attr('href');
#                 // 把目前點擊到的 li 頁籤加上 .active
#                 // 並把兄弟元素中有 .active 的都移除 class
#                 $this.addClass('active2').siblings('.active2').removeClass('active2');
#                 // 淡入相對應的內容並隱藏兄弟元素
#                 $(_clickTab).stop(false, true).fadeIn().siblings().hide();
#
#                 return false;
#             }).find('a').focus(function () {
#                 this.blur();
#             });
#         });
#     </script>
# <script type="text/javascript">
#         $(function () {
#             // 幫 #qaContent 的 ul 子元素加上 .accordionPart
#             // 接著再找出 li 中的第一個 div 子元素加上 .qa_title
#             // 並幫其加上 hover 及 click 事件
#             // 同時把兄弟元素加上 .qa_content 並隱藏起來
#             $('#qaContent ul').addClass('accordionPart').find('li div:nth-child(1)').addClass('qa_title').hover(function () {
#                 $(this).addClass('qa_title_on');
#             }, function () {
#                 $(this).removeClass('qa_title_on');
#             }).click(function () {
#                 // 當點到標題時，若答案是隱藏時則顯示它，同時隱藏其它已經展開的項目
#                 // 反之則隱藏
#                 var $qa_content = $(this).next('div.qa_content');
#
#                 var className = $(this).find('i').attr("class");
#                 $(this).find('i').removeClass(className);
#                 $(this).find('i').addClass(function () {
#                     return (className == "fa fa-chevron-circle-down") ? 'fa fa-chevron-circle-up' : 'fa fa-chevron-circle-down';
#                 });
#
#                 $qa_content.slideToggle();
#             }).siblings().addClass('qa_content').hide();
#             $('#qaContent ul li').eq(0).find('div:first').click();
#             $('#qaContent ul li').eq(1).find('div:first').click();
#         });
#
#         function addClickCount(prodId) {
#             var memberId = $('input[name=memberId]').val();
#             $.ajax({
#                 url: "/Marketing/AddClickCount",
#                 data: { prodId: prodId, memberId: memberId },
#                 type: "POST",
#                 dataType: 'text',
#                 success: function () {
#                 }
#             });
#         };
#
#         function addCategoryClick(categoryId) {
#             var memberId = $('input[name=memberId]').val();
#             $.ajax({
#                 url: "/Marketing/AddCategoryClick",
#                 data: { categoryId: categoryId, memberId: memberId },
#                 type: "POST",
#                 dataType: 'text',
#                 success: function () {
#                 }
#             });
#         };
#
#     </script>
# <script src="/Scripts/jquery.blockUI.js"></script>
# <script src="/js/flycan.js"></script>
# <script src="/Scripts/angular.min.js"></script>
# <script src="/Scripts/angular-sanitize.min.js"></script>
# <script src="/Scripts/angular-animate.min.js"></script>
# <script src="/Scripts/ui-bootstrap-custom-build/ui-bootstrap-custom-tpls-0.13.3.min.js"></script>
# <script src="/Scripts/js.js?v=1.0.11"></script>
# <script src="/Scripts/ShoppingCart.js?v=1.0.3"></script>
# <script>
#             function ScupioAddtocart(id, amount) {
#                 var sc_uid = "";
#                 if ($.cookie('kie') != "" && $.cookie('kie') != undefined)
#                     sc_uid = $.cookie('kie');
#
#                 (window._bwtm = window._bwtm || []).push({
#                     "mid": 240,
#                     "uid": sc_uid,
#                     "event": "addtocart",
#                     "eventdata": [{ iid: id, ch: "", qty: amount }]
#                 });
#                 (scupioconv = window.scupioconv || []).push({ bwp: 894, bwpid: 'prebuy' });
#             }
#
#             function ScupioShare(id, categoryid) {
#                 var sc_uid = "";
#                 if ($.cookie('kie') != "" && $.cookie('kie') != undefined)
#                     sc_uid = $.cookie('kie');
#                 (window._bwtm = window._bwtm || []).push({
#                     "mid": 240,
#                     "uid": sc_uid,
#                     "event": "share",
#                     "eventdata": [{ iid: id, ch: categoryid, media: "Facebook" }]
#                 });
#                 (scupioconv = window.scupioconv || []).push({ bwp: 894, bwpid: 'action' });
#
#             }
#
#             function ScupioSearch(kw, sitem, pi) {
#                 var dev_width = (window.innerWidth > 0) ? window.innerWidth : screen.width;
#                 var sc_pid = "search";
#                 if (parseInt(dev_width) <= 768)
#                     sc_pid = "search_m";
#                 var sc_uid = "";
#                 if ($.cookie('kie') != "" && $.cookie('kie') != undefined)
#                     sc_uid = $.cookie('kie');
#
#                 (window._bwtm = window._bwtm || []).push({
#                     "mid": 240,
#                     "pid": sc_pid,
#                     "kw": kw,
#                     "sitem": sitem,
#                     "uid": sc_uid,
#                     "pi": pi
#                 });
#                 (scupioconv = window.scupioconv || []).push({ bwp: 894, bwpid: 'action' });
#             }
#         </script>
# <script async="" class="executed" src="//rec.scupio.com/recweb/js/rec.js"></script>
# <script async="" src="//img.scupio.com/js/conv.js"></script>
# <script src="//d17m68fovwmgxj.cloudfront.net/js/appier-track-v1.7.js"></script>
# <script src="/Scripts/funAppier.js"></script>
# <script>
#      (function(w, d, s, m) {
#          var f = d.getElementsByTagName('script')[0],
#              j = d.createElement('script'),
#              ns = 'APPIER_RETARGET';
#          w._appierSendQueue = [];
#          w['appierRetargetJson'] = { id: s, site: m};
#          j.async = true;
#          j.src = '//d17m68fovwmgxj.cloudfront.net/js/rt/track.js';
#          f.parentNode.insertBefore(j, f);
#          !w[ns] && (w[ns] = {});
#          (!w[ns].send) && (w[ns].send = function(j){
#              w._appierSendQueue.push(j);
#          });
#      })(window, document, 'Ows2', 'famicloud.com.tw');
#
# </script>
# <!-- Facebook Pixel Code -->
# <script>
#         !function (f, b, e, v, n, t, s) {
#             if (f.fbq) return; n = f.fbq = function () {
#                 n.callMethod ?
#                 n.callMethod.apply(n, arguments) : n.queue.push(arguments)
#             }; if (!f._fbq) f._fbq = n;
#             n.push = n; n.loaded = !0; n.version = '2.0'; n.queue = []; t = b.createElement(e); t.async = !0;
#             t.src = v; s = b.getElementsByTagName(e)[0]; s.parentNode.insertBefore(t, s)
#         }(window,
#         document, 'script', 'https://connect.facebook.net/en_US/fbevents.js');
#
#         fbq('init', '726275000837736');
#         fbq('track', "PageView");
#     </script>
# <noscript>
#         &lt;img height="1" width="1" style="display:none"
#              src="https://www.facebook.com/tr?id=726275000837736&amp;ev=PageView&amp;noscript=1" /&gt;
#     </noscript>
# <!-- End Facebook Pixel Code -->
# <script>
#         function FBAddToCart(name, category, prod, price) {
#             fbq('track', 'AddToCart', {
#                 content_name: name,
#                 content_category: category,
#                 content_ids: [prod],
#                 content_type: 'product',
#                 value: price,
#                 currency: 'TWD'
#             });
#         }
#     </script>
# <script type="text/javascript">
#             var tagtoo_advertiser_id = 408;
#             var tagtoo_ga = document.createElement('script');
#             tagtoo_ga.type = 'text/javascript';
#             tagtoo_ga.async = true;
#             tagtoo_ga.src = '//ad.tagtoo.co/media/ad/track.js';
#             var tagtoo_s = document.getElementsByTagName('script')[0];
#             tagtoo_s.parentNode.insertBefore(tagtoo_ga, tagtoo_s);
#         </script>
# <script async="" src="//cm.g.doubleclick.net/pixel?google_nid=bw_cookie&amp;google_cm&amp;google_ula=3323379&amp;google_hm=YzE0ODg1NTI2ODM5ODR4YWFmMjFiMjZl&amp;layout=js&amp;fp=1"></script>
# <link href="/menumobile/css/jquery-sliding-menu.css" rel="stylesheet"/>
# <script>
#     $(function () {
#         $("#menuselect a").each(function () {
#             if ($(this).next().is("ul")) {
#                 $(this).addClass("nav");
#             }
#         });
#
#
#         $("#menuselect a").on('click', function () {
#             if ($(this).attr("href") == "" || $(this).attr("href") == undefined) {
#                 $(this).next().toggle({ "display": "block" });
#                 $(this).toggleClass("navn");
#             }
#         });
#     });
#
# </script>
# <div id="menuselect">
# <ul>
# <li>
# <a class="nav"><i class="fa fa-bars"></i> 全分類商品</a>
# <ul>
# <li>
# <a class="nav">限時好康</a>
# <ul>
# <li>
# <a class="nav">限量9折</a>
# <ul>
# <li><a href="/Branchs/Branch/Index/1/563/564">限量搶購9折</a></li>
# </ul>
# </li>
# <li>
# <a class="nav">限量79折</a>
# <ul>
# <li><a href="/Branchs/Branch/Index/1/287/288">限量搶購79折</a></li>
# </ul>
# </li>
# <li>
# <a class="nav">超值買一送一</a>
# <ul>
# <li><a href="/Branchs/Branch/Index/1/908/914">買一送一</a></li>
# </ul>
# </li>
# <li>
# <a class="nav">即期品半價</a>
# <ul>
# <li><a href="/Branchs/Branch/Index/1/565/566">半價下殺</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li>
# <a class="nav">鮮食家推薦</a>
# <ul>
# <li>
# <a class="nav">Top30商品</a>
# <ul>
# <li><a href="/Branchs/Branch/Index/312/313/316">熱銷排行</a></li>
# </ul>
# </li>
# <li>
# <a class="nav">假日追劇必吃</a>
# <ul>
# <li><a href="/Branchs/Branch/Index/312/895/896">超順嘴電視美食</a></li>
# <li><a href="/Branchs/Branch/Index/312/895/897">上班這黨事推薦</a></li>
# </ul>
# </li>
# <li>
# <a class="nav">百元內美食</a>
# <ul>
# <li><a href="/Branchs/Branch/Index/312/356/357">35元~59元</a></li>
# <li><a href="/Branchs/Branch/Index/312/356/358">60元~99元</a></li>
# </ul>
# </li>
# <li>
# <a class="nav">火鍋超值組</a>
# <ul>
# <li><a href="/Branchs/Branch/Index/312/548/549">火鍋超值組</a></li>
# </ul>
# </li>
# <li>
# <a class="nav">享受早午餐</a>
# <ul>
# <li><a href="/Branchs/Branch/Index/312/607/608">美味早午餐</a></li>
# </ul>
# </li>
# <li>
# <a class="nav">露營方便吃</a>
# <ul>
# <li><a href="/Branchs/Branch/Index/312/504/505">野炊生鮮</a></li>
# <li><a href="/Branchs/Branch/Index/312/504/506">即食好菜</a></li>
# <li><a href="/Branchs/Branch/Index/312/504/507">飯麵主食</a></li>
# <li><a href="/Branchs/Branch/Index/312/504/508">野炊蔬菜</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li>
# <
a></li>
# <li><a href="/Branchs/Branch/Index/879/909/936">龜甲萬</a></li>
# <li><a href="/Branchs/Branch/Index/879/909/1001">承味</a></li>
# <li><a href="/Branchs/Branch/Index/879/909/1015">奧利塔</a></li>
# <li><a href="/Branchs/Branch/Index/879/909/1041">Agnesi</a></li>
# <li><a href="/Branchs/Branch/Index/879/909/1046">Dancing pig</a></li>
# <li><a href="/Branchs/Branch/Index/879/909/1065">合將</a></li>
# <li><a href="/Branchs/Branch/Index/879/909/1073">百鈉瑞</a></li>
# <li><a href="/Branchs/Branch/Index/879/909/1076">泰國deSIAM</a></li>
# <li><a href="/Branchs/Branch/Index/879/909/1091">阿春肉燥</a></li>
# <li><a href="/Branchs/Branch/Index/879/909/1100">家華</a></li>
# <li><a href="/Branchs/Branch/Index/879/909/1101">熱帶玫瑰</a></li>
# <li><a href="/Branchs/Branch/Index/879/909/1121">桃米泉</a></li>
# <li><a href="/Branchs/Branch/Index/879/909/1122">辣椒叔叔</a></li>
# <li><a href="/Branchs/Branch/Index/879/909/1124">李錦記</a></li>
# <li><a href="/Branchs/Branch/Index/879/909/1125">穀盛</a></li>
# <li><a href="/Branchs/Branch/Index/879/909/1127">高印</a></li>
# <li><a href="/Branchs/Branch/Index/879/909/1128">恒順</a></li>
# <li><a href="/Branchs/Branch/Index/879/909/1129">松井</a></li>
# <li><a href="/Branchs/Branch/Index/879/909/1130">遠東</a></li>
# <li><a href="/Branchs/Branch/Index/879/909/1131">美味大師</a></li>
# <li><a href="/Branchs/Branch/Index/879/909/1133">工研</a></li>
# <li><a href="/Branchs/Branch/Index/879/909/1135">十全</a></li>
# <li><a href="/Branchs/Branch/Index/879/909/1137">江記</a></li>
# <li><a href="/Branchs/Branch/Index/879/909/1138">安安</a></li>
# <li><a href="/Branchs/Branch/Index/879/909/1139">貴州</a></li>
# <li><a href="/Branchs/Branch/Index/879/909/1140">民生</a></li>
# <li><a href="/Branchs/Branch/Index/879/909/1142">台塑</a></li>
# <li><a href="/Branchs/Branch/Index/879/909/1143">慈光BB</a></li>
# ...
# <li><a href="/Home/Static?page=Delivery&amp;index=2">運費說明</a></li>
# <li><a href="/Home/Static?page=Delivery&amp;index=1">購買商品追蹤查詢</a></li>
# <li><a href="/Home/Static?page=Delivery&amp;index=4">退換貨須知</a></li>
# </ul>
# </div>
# <div class="pull-left ha">
# <h5><span class="fa fa-user"></span>會員中心</h5>
# <ul>
# <li><a href="/Home/Static?page=MemberClause">會員權益條款</a></li>
# <li><a href="/Home/Static?page=HowJoin">加入會員的方式</a></li>
# <li><a href="/Member/MemberManager/Forget">忘記帳號與密碼</a></li>
# <li><a href="/Member/MemberCenter/MemberEdit">修改會員資料</a></li>
# <li><a href="/Member/MemberCenter/BonusElse">加菜金查詢</a></li>
# <li><a href="/Member/MemberCenter/Edm">訂閱優惠情報</a></li>
# </ul>
# </div>
# <div class="pull-left ha bor_right">
# <h5><span class="fa fa-archive"></span>公司簡介</h5>
# <ul>
# <li><a href="/Home/Static?page=CompanyIntroduction">公司簡介</a></li>
# <li><a href="/Home/ContactUs">聯絡我們</a></li>
# <li><a href="/Home/Busines">招商專線</a></li>
# <li><a href="/Home/Static?page=Privacy">隱私保護</a></li>
# <li>
# <a href="http://www.104.com.tw/jobbank/custjob/index.php?r=cust&amp;j=4c3e466f383a426b34363e673c423a1d02d2d2d72444a602644j99" target="_blank">徵人啟事</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </footer><!-------------- ↑版尾 ---------------->
# <div class="footer_down">
# <div class="wrap clearfix">
# <div class="foot_logo pull-left">
# <img src="/img/logo.png"/>
# </div>
# <div class="info pull-left">
# <ul>
# <li> </li>
# <li>地址：台北市大安區忠孝東路四段218號13樓</li>
# </ul>
# </div>
# <div class="info02 pull-right">
# <ul>
# <li>法律顧問：德宇國際法律事務所</li>
# <li>鮮食家由家庭雲端股份有限公司經營管理 非經本公司書面同意 請勿任意轉載網站內容</li>
# </ul>
# </div>
# </div>
# </div>
# <!-- ↓手機版 版尾  -->
# <div class="ng-scope" id="mobile-footer" ng-controller="BuyCartCtrl">
# <ul>
# <li id="AA"><a href="/"><p class="icon"><i class="fa fa-home"></i></p><p>首頁</p></a></li>
# <li id="BB"><a href="#"><p class="icon"><i class="fa fa-search"></i></p><p>搜尋</p></a></li>
# <li id="DD"><a ng-click="Pay();"><p class="icon" style="position:relative"><span class="ng-binding" id="shoppingCnt" style="position:absolute;top:-4px;right:7px;z-index:3;font-size:15px">0</span><img src="/img/bonus_nember_bg.png" style="width:30px;position:absolute; top:-10px; right:0px"/><i class="fa fa-shopping-cart"></i></p><p>購物車</p></a></li>
# <li id="EE"><a href="/Member/MemberCenter"><p class="icon"><i class="fa fa-user"></i></p><p>會員中心</p></a></li>
# </ul>
# </div>
# <!-- ↑手機版 版尾  -->
# <!-- Include modernizr-2.8.3.min.js -->
# <script src="/assets/js/modernizr-2.8.3.min.js"></script>
# <!-- Include jquery.min.js plugin -->
# <!-- Include magnific-popup.min.js -->
# <script src="/assets/js/jquery.magnific-popup.min.js"></script>
# <!-- Javascript Plugins  -->
# <script src="/assets/js/plugins.js"></script>
# <!-- Custom Functions  -->
# <script src="/assets/js/functions.js"></script>
# <script src="/assets/js/wow.min.js"></script>
# <script src="/assets/js/jquery.ajaxchimp.min.js"></script>
# <script src="/jqueryui/jquery-ui.min.js"></script>
# <script>
#         $(document).ready(function () {
#
#             /* -------- One page Navigation ----------*/
#             $('#main-menu #menu').onePageNav({
#                 currentClass: 'active',
#                 changeHash: false,
#                 scrollSpeed: 1500,
#                 scrollThreshold: 0.5,
#                 scrollOffset: 95,
#                 filter: ':not(.sub-menu a, .not-in-home)',
#                 easing: 'swing'
#             });
#
#
#             /*----------- Google Map - with support of gmaps.js ----------------*/
#
#             function isMobile() {
#                 return ('ontouchstart' in document.documentElement);
#             }
#
#             function init_gmap() {
#                 if (typeof google == 'undefined') return;
#                 var options = {
#                     center: [-37.817331, 144.955652],
#                     zoom: 15,
#                     mapTypeControl: true,
#                     mapTypeControlOptions: {
#                         style: google.maps.MapTypeControlStyle.DROPDOWN_MENU
#                     },
#                     navigationControl: true,
#                     scrollwheel: false,
#                     streetViewControl: true
#                 }
#
#                 if (isMobile()) {
#                     options.draggable = false;
#                 }
#
#                 $('#googleMaps').gmap3({
#                     map: {
#                         options: options
#                     },
#                     marker: {
#                         latLng: [-37.817331, 144.955652],
#                         options: { icon: 'images/mapicon.png' }
#                     }
#                 });
#             }
#
#             init_gmap();
#         });
#     </script>
# <!-- body_google嵌入碼start -->
# <!-- 再行銷start -->
# <script type="text/javascript">
#     /* <![CDATA[ */
#     var google_conversion_id = 960762688;
#     var google_custom_params = window.google_tag_params;
#     var google_remarketing_only = true;
#     /* ]]> */
# </script>
# <script src="//www.googleadservices.com/pagead/conversion.js" type="text/javascript">
# </script><iframe allowtransparency="true" frameborder="0" height="13" hspace="0" marginheight="0" marginwidth="0" name="google_conversion_frame" scrolling="no" src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/960762688/?random=1488552683698&amp;cv=8&amp;fst=1488552683698&amp;num=1&amp;fmt=1&amp;guid=ON&amp;u_h=1080&amp;u_w=1920&amp;u_ah=1040&amp;u_aw=1920&amp;u_cd=32&amp;u_his=1&amp;u_tz=480&amp;u_java=false&amp;u_nplug=0&amp;u_nmime=0&amp;frm=0&amp;url=https%3A%2F%2Fwww.famicloud.com.tw%2FBranchs%2FBranch%2FIndex%2F5%2F272%2F1271&amp;tiba=%E4%B8%AD%E7%A5%A5-%E9%AE%AE%E9%A3%9F%E5%AE%B6%E9%9B%B2%E7%AB%AF%E5%86%B0%E7%AE%B1" title="Google conversion frame" vspace="0" width="300"></iframe>
# <noscript>
#     &lt;div style="display:inline;"&gt;
#         &lt;img height="1" width="1" style="border-style:none;" alt="" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/960762688/?value=0&amp;amp;guid=ON&amp;amp;script=0" /&gt;
#     &lt;/div&gt;
# </noscript>
# <!-- 再行銷end -->
# <!-- 流量統計start -->
# <script>
#     (function (i, s, o, g, r, a, m) {
#         i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {
#             (i[r].q = i[r].q || []).push(arguments)
#         }, i[r].l = 1 * new Date(); a = s.createElement(o),
#         m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
#     })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
#     ga('create', 'UA-57228033-1', 'auto');
#     ga('require', 'displayfeatures');
#     ga('send', 'pageview');
#
#
#     //yahoo
#     window.onload = function () {
#         (function (w, d, t, r, u) { var f, n, i; w[u] = w[u] || [], f = function () { var o = { ti: "4012501" }; o.q = w[u], w[u] = new UET(o), w[u].push("pageLoad") }, n = d.createElement(t), n.src = r, n.async = 1, n.onload = n.onreadystatechange = function () { var s = this.readyState; s && s !== "loaded" && s !== "complete" || (f(), n.onload = n.onreadystatechange = null) }, i = d.getElementsByTagName(t)[0], i.parentNode.insertBefore(n, i) })(window, document, "script", "//bat.bing.com/bat.js", "uetq");
#     }
#
# </script>
# <!-- 流量統計end -->
# <!-- Start Alexa Certify Javascript -->
# <script type="text/javascript">
#
#     _atrk_opts = { atrk_acct: "NZrNk1ao6C525T", domain: "famicloud.com.tw", dynamic: true };
#
#     (function () { var as = document.createElement('script'); as.type = 'text/javascript'; as.async = true; as.src = "https://d31qbv1cthcecs.cloudfront.net/atrk.js"; var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(as, s); })();
#
# </script>
# <noscript>&lt;img src="https://d5nxst8fruw4z.cloudfront.net/atrk.gif?account=NZrNk1ao6C525T" style="display:none" height="1" width="1" alt="" /&gt;</noscript>
# <!-- End Alexa Certify Javascript -->
# <!-- body_google嵌入碼end -->
# <script type="application/javascript">(function(w,d,t,r,u){w[u]=w[u]||[];w[u].push({'projectId':'1000936933826','properties':{'pixelId':'427548'}});var s=d.createElement(t);s.src=r;s.async=true;s.onload=s.onreadystatechange=function(){var y,rs=this.readyState,c=w[u];if(rs&&rs!="complete"&&rs!="loaded"){return}try{y=YAHOO.ywa.I13N.fireBeacon;w[u]=[];w[u].push=function(p){y([p])};y(c)}catch(e){}};var scr=d.getElementsByTagName(t)[0],par=scr.parentNode;par.insertBefore(s,scr)})(window,document,"script","https://s.yimg.com/wi/ytc.js","dotq");</script>
# <ul class="ui-menu ui-widget ui-widget-content ui-autocomplete ui-front" id="ui-id-1" style="display: none;" tabindex="0"></ul><div aria-live="assertive" aria-relevant="additions" class="ui-helper-hidden-accessible" role="status"></div><script id="" type="text/javascript">(function(){function f(a,c){var b=document.createElement("script");b.type="text/javascript";b.async=!0;b.src=a;var d=document.getElementsByTagName("script")[0];d.parentNode.insertBefore(b,d);b.onload=function(){c(a)};b.onreadystatechange=function(){"complete"!=b.readyState&&"loaded"!=b.readyState||c(a)}}try{var a=["//cdn.tagtoo.com.tw/gtm/js/tagtoosdk.js","//cdn.tagtoo.com.tw/gtm/js/track2.js"];206!=tagtoo_advertiser_id&&a.push("//cdn.tagtoo.com.tw/gtm/js/jquery.js");var c={578:"clubmed",177:"wiwi",
# 314:"janlov",387:"hotcar"};tagtoo_advertiser_id in c||a.push("//cdn.tagtoo.com.tw/ec/js/ec.js");var e="["+a.join("][")+"]";e.replace("[]","");for(c=0;c<a.length;c++)f(a[c],function(a){(e=e.replace("["+a+"]",""))||window.TagtoodataLayer.push({event:"main.default_loaded"})})}catch(d){a=window.TagtoodataLayer,a.push({event:"track.Error",jsError:{tag:"Main default_load",error:d}})}})();</script><script class="ywa-1000936933826" defer="" id="ywa-1488552684484-459917" src="https://sp.analytics.yahoo.com/sp.pl?a=1000936933826&amp;jsonp=YAHOO.ywa.I13N.handleJSONResponse&amp;d=Fri%2C%2003%20Mar%202017%2014%3A51%3A24%20GMT&amp;n=-8&amp;b=%E4%B8%AD%E7%A5%A5-%E9%AE%AE%E9%A3%9F%E5%AE%B6%E9%9B%B2%E7%AB%AF%E5%86%B0%E7%AE%B1&amp;.yp=427548&amp;f=https%3A%2F%2Fwww.famicloud.com.tw%2FBranchs%2FBranch%2FIndex%2F5%2F272%2F1271&amp;enc=UTF-8" type="application/javascript"></script><script id="" type="text/javascript">(function(){Tagtoo.UserInfo=Tagtoo.Cookie.getItem("_TUCI")||{};Tagtoo.UserInfo_T=Tagtoo.Cookie.getItem("_TUCI_T")||{};Tagtoo.track.FBInfo.sessionNumber();var b={578:"clubmed",177:"wiwi",314:"janlov",387:"hotcar"},d=window.location.href,c=tagtoo_advertiser_id in b?tagtoo_advertiser_id:Tagtoo.EC.parseEcid(d)||tagtoo_advertiser_id,k=Tagtoo.Core.decodeQueryData(d);if(k.utm_source){if(k.utm_source.match(/tagtoo/)){var f=(new Date).getTime(),a=Tagtoo.Cookie.getItem("t_cl_30",!1),e=Tagtoo.Cookie.getItem("t_cl_7",
# !1),g=Tagtoo.Cookie.getItem("t_cl",!1),h=2592E3;a&&(a=parseInt(a),a=(f-a)/1E3/60/60/24,30<a&&Tagtoo.Cookie.removeItem("t_cl_30"));e&&(a=parseInt(e),a=(f-a)/1E3/60/60/24,7<a&&(Tagtoo.Cookie.hasItem("t_cl_30")||Tagtoo.Cookie.setItem("t_cl_30",e,h),Tagtoo.Cookie.removeItem("t_cl_7")));g&&(e=parseInt(g),a=(f-e)/1E3/60/60/24,7<a&&30>=a&&!Tagtoo.Cookie.hasItem("t_cl_30")?Tagtoo.Cookie.setItem("t_cl_30",g,h):7>=a&&!Tagtoo.Cookie.hasItem("t_cl_7")&&Tagtoo.Cookie.setItem("t_cl_7",g,h));Tagtoo.Cookie.setItem("t_cl",
# f,h)}Tagtoo.Cookie.setItem("_TUCU",k.utm_source)}d=tagtoo_advertiser_id in b?"unknown":Tagtoo.EC.parseKey(c,d);b={};b.ec_id=c;b.page_key=d;Tagtoo.UserInfo.ECId=c;Tagtoo.UserInfo.hostname=document.location.hostname;c=window.TagtoodataLayer;c.push({page_info:b});c.push({event:"main.initialized"})})();</script><script id="" type="text/javascript">(function(a,b,d,c,e){a[c]=a[c]||[];a[c].push({"child.start":(new Date).getTime()});a=b.getElementsByTagName(d)[0];b=b.createElement(d);b.async=!0;b.src="//www.googletagmanager.com/gtm.js?id\x3d"+e+("dataLayer"!=c?"\x26l\x3d"+c:"");a.parentNode.insertBefore(b,a)})(window,document,"script","TagtoodataLayer","GTM-K796GD");</script><script id="" type="text/javascript">(function(){var b;b="288385784845913,527009064159190;404012299753340,486052381541937;356152267927357,486052381541937".match(/[^;]+/g);for(var c=0;c<b.length;c++){var a=b[c].split(","),a=a[0];Tagtoo.track.FBTrack(a,"PixelInitialized");Tagtoo.track.FBTrack(a,"PageView")}})();</script><script id="" type="text/javascript">(function(){Tagtoo.track.FBInfo.pageView()})();</script><script id="" type="text/javascript">(function(c,b,d,g,e){var a;a="10006212,10000".match(/[^;]+/g);var f=a[0].split(",");a=f[0];f=f[1];c[e]=c[e]||[];c[e].push({projectId:f,properties:{pixelId:a}});a=b.createElement(d);a.src=g;a.async=!0;a.onload=a.onreadystatechange=function(){var a,b=this.readyState,d=c[e];if(!b||"complete"==b||"loaded"==b)try{a=YAHOO.ywa.I13N.fireBeacon,c[e]=[],c[e].push=function(b){a([b])},a(d)}catch(f){}};b=b.getElementsByTagName(d)[0];d=b.parentNode;d.insertBefore(a,b)})(window,document,"script","https://s.yimg.com/wi/ytc.js",
# "dotq");</script><script class="ywa-10000" defer="" id="ywa-1488552684892-281427" src="https://sp.analytics.yahoo.com/sp.pl?a=10000&amp;jsonp=YAHOO.ywa.I13N.handleJSONResponse&amp;d=Fri%2C%2003%20Mar%202017%2014%3A51%3A24%20GMT&amp;n=-8&amp;b=%E4%B8%AD%E7%A5%A5-%E9%AE%AE%E9%A3%9F%E5%AE%B6%E9%9B%B2%E7%AB%AF%E5%86%B0%E7%AE%B1&amp;.yp=10006212&amp;f=https%3A%2F%2Fwww.famicloud.com.tw%2FBranchs%2FBranch%2FIndex%2F5%2F272%2F1271&amp;enc=UTF-8" type="application/javascript"></script><script id="" type="text/javascript">(function(){try{var b=!!$('a[href$\x3d"Logout"]').length;if(b){var c=$("#userDisplayName").text(),a=window.TagtoodataLayer;a.push({event:"track.isMember",member_id:c})}}catch(d){a=window.TagtoodataLayer,a.push({event:"track.Error",jsError:{tag:"Event track.isMember",error:d}})}})();</script><script id="" type="text/javascript">(function(){window.TagtoodataLayer.push({event:"track.impression"})})();</script><script id="" type="text/javascript">(function(){try{$(".buy-botton").on("click",function(){var a=$(this).parents("#Curator-big, #SmallMedium"),b="https://www.famicloud.com.tw"+a.find("a:first").attr("href"),a={name:a.find(".Name").text(),sku:Tagtoo.EC.parseKey(google_tag_manager["GTM-K796GD"].macro('gtm6'),b),quantity:a.find(":selected").text(),price:a.find(".SaleNum").text()},b=window.TagtoodataLayer;b.push({event:"track.addToCart",addToCartDetail:[a],addToCart_products:[a.sku]})})}catch(a){var c=window.TagtoodataLayer;c.push({event:"track.Error",
# jsError:{tag:"Event track.addToCart Category",error:a}})}})();</script><div id="blockMes" style="display: none; cursor: default;">
# <img src="/img/ajax-loader.gif"/>
# </div><iframe name="ret_if" src="//famicloud-com-tw.b.appier.net/rtworker4.html?url=https://www.famicloud.com.tw/Branchs/Branch/Index/5/272/1271" style="display: none; width: 1px; height: 1px;"></iframe><script id="" type="text/javascript">(function(){try{window.__tagtoo_fbinfo=function(){if(window.Tagtoo){var a;a="288385784845913,527009064159190;404012299753340,486052381541937;356152267927357,486052381541937".match(/[^;]+/g);for(var b=0;b<a.length;b++){var c=a[b].split(","),c=c[0];Tagtoo.track.FBTrack(c,"UserInfo",Tagtoo.UserInfo)}}else setTimeout(__tagtoo_fbinfo,3E3)},__tagtoo_fbinfo()}catch(a){var d=window.TagtoodataLayer;d.push({event:"track.Error",jsError:{tag:"Pixel Facebook UserInfo",error:a}})}})();</script><div id="batBeacon0.9559644481632859" style="width:0px; height:0px; display:none; visibility:hidden;"><img height="0" id="batBeacon0.6095964680425823" src="https://bat.r.msn.com/action-uic/0?ti=4012501&amp;Ver=2&amp;mid=8c49e9c0-ca1b-e241-e37c-3cb84e039d2e&amp;evt=pageLoad&amp;lt=8854&amp;pi=0&amp;lg=zh-TW&amp;sw=1920&amp;sh=1080&amp;sc=32&amp;tl=中祥-鮮食家雲端冰箱&amp;p=https%3A%2F%2Fwww.famicloud.com.tw%2FBranchs%2FBranch%2FIndex%2F5%2F272%2F1271&amp;r=&amp;rn=647242" style="width:0px; height:0px; display:none; visibility:hidden;" width="0"/><img height="0" id="batBeacon0.4622406221460551" src="https://bat.bing.com/action/0?ti=4012501&amp;Ver=2&amp;mid=8c49e9c0-ca1b-e241-e37c-3cb84e039d2e&amp;evt=pageLoad&amp;lt=8854&amp;pi=0&amp;lg=zh-TW&amp;sw=1920&amp;sh=1080&amp;sc=32&amp;tl=中祥-鮮食家雲端冰箱&amp;p=https%3A%2F%2Fwww.famicloud.com.tw%2FBranchs%2FBranch%2FIndex%2F5%2F272%2F1271&amp;r=&amp;rn=644006" style="width:0px; height:0px; display:none; visibility:hidden;" width="0"/></div></body></html>

# %%
soup.select('#SmallMedium > a')
# Out:
# [<a href="/Branchs/Branch/Product/5/272/1271/7034">
#  <img ng-src="https://familycloud.blob.core.windows.net/products/10004348_1.jpg" src="https://familycloud.blob.core.windows.net/products/10004348_1.jpg"/>
#  <b class="special ng-binding"> </b>
#  <b class="Name ng-binding">中祥<br/>自然の顏獨享包-香椿蘇打餅(75g/包)</b>
#  <b class="OriginalPrice ng-binding">原價$32</b>
#  <b class="OnSalePrice">網路價$<b class="SaleNum ng-binding">29</b></b>
#  <!-- ngIf: item.TempLayer == 3 || item.TempLayer == null -->
#  <!-- ngIf: item.TempLayer == 1 --><b class="ProductLabel ng-scope" ng-if="item.TempLayer == 1"><img src="/img/t2.png" title="此為常溫商品，滿490元免運費，中午前訂購隔日送達。"/></b><!-- end ngIf: item.TempLayer == 1 -->
#  <!-- ngIf: item.TempLayer == 2 -->
#  <!-- ngIf: item.TempLayer == 4 -->
#  </a>,
#  <a class="ng-scope" href="javascript:void(0)" ng-if="item.ProductSalesQty &gt; 0"><b class="buy-botton" ng-click="AddCart(item)"><div id="buy-s"></div></b></a>,
#  <a href="/Branchs/Branch/Product/5/272/1271/7033">
#  <img ng-src="https://familycloud.blob.core.windows.net/products/10004347_1.jpg" src="https://familycloud.blob.core.windows.net/products/10004347_1.jpg"/>
#  <b class="special ng-binding"> </b>
#  <b class="Name ng-binding">中祥<br/>自然の顏獨享包-蔬菜蘇打餅(80g/包)</b>
#  <b class="OriginalPrice ng-binding">原價$32</b>
#  <b class="OnSalePrice">網路價$<b class="SaleNum ng-binding">29</b></b>
#  <!-- ngIf: item.TempLayer == 3 || item.TempLayer == null -->
#  <!-- ngIf: item.TempLayer == 1 --><b class="ProductLabel ng-scope" ng-if="item.TempLayer == 1"><img src="/img/t2.png" title="此為常溫商品，滿490元免運費，中午前訂購隔日送達。"/></b><!-- end ngIf: item.TempLayer == 1 -->
#  <!-- ngIf: item.TempLayer == 2 -->
#  <!-- ngIf: item.TempLayer == 4 -->
#  </a>,
#  <a class="ng-scope" href="javascript:void(0)" ng-if="item.ProductSalesQty &gt; 0"><b class="buy-botton" ng-click="AddCart(item)"><div id="buy-s"></div></b></a>,
#  <a href="/Branchs/Branch/Product/5/272/1271/7032">
#  <img ng-src="https://familycloud.blob.core.windows.net/products/10004346_1.jpg" src="https://familycloud.blob.core.windows.net/products/10004346_1.jpg"/>
#  <b class="special ng-binding"> </b>
#  <b class="Name ng-binding">中祥<br/>自然の顏獨享包-紫菜蘇打餅(80g/包)</b>
#  <b class="OriginalPrice ng-binding">原價$32</b>
#  <b class="OnSalePrice">網路價$<b class="SaleNum ng-binding">29</b></b>
#  <!-- ngIf: item.TempLayer == 3 || item.TempLayer == null -->
#  <!-- ngIf: item.TempLayer == 1 --><b class="ProductLabel ng-scope" ng-if="item.TempLayer == 1"><img src="/img/t2.png" title="此為常溫商品，滿490元免運費，中午前訂購隔日送達。"/></b><!-- end ngIf: item.TempLayer == 1 -->
#  <!-- ngIf: item.TempLayer == 2 -->
#  <!-- ngIf: item.TempLayer == 4 -->
#  </a>,
#  <a class="ng-scope" href="javascript:void(0)" ng-if="item.ProductSalesQty &gt; 0"><b class="buy-botton" ng-click="AddCart(item)"><div id="buy-s"></div></b></a>,
#  <a href="/Branchs/Branch/Product/5/272/1271/7030">
#  <img ng-src="https://familycloud.blob.core.windows.net/products/10004344_1.jpg" src="https://familycloud.blob.core.windows.net/products/10004344_1.jpg"/>
#  <b class="special ng-binding"> </b>
#  <b class="Name ng-binding">中祥<br/>中祥蔬菜餅乾透明包裝(140g/包)</b>
#  <b class="OriginalPrice ng-binding">原價$39</b>
#  <b class="OnSalePrice">網路價$<b class="SaleNum ng-binding">29</b></b>
#  <!-- ngIf: item.TempLayer == 3 || item.TempLayer == null -->
#  <!-- ngIf: item.TempLayer == 1 --><b class="ProductLabel ng-scope" ng-if="item.TempLayer == 1"><img src="/img/t2.png" title="此為常溫商品，滿490元免運費，中午前訂購隔日送達。"/></b><!-- end ngIf: item.TempLayer == 1 -->
#  <!-- ngIf: item.TempLayer == 2 -->
#  <!-- ngIf: item.TempLayer == 4 -->
#  </a>,
#  <a class="ng-scope" href="javascript:void(0)" ng-if="item.ProductSalesQty &gt; 0"><b class="buy-botton" ng-click="AddCart(item)"><div id="buy-s"></div></b></a>,
#  <a href="/Branchs/Branch/Product/5/272/1271/7029">
#  <img ng-src="https://familycloud.blob.core.windows.net/products/10004343_1.jpg" src="https://familycloud.blob.core.windows.net/products/10004343_1.jpg"/>
#  <b class="special ng-binding"> </b>
#  <b class="Name ng-binding">中祥<br/>中祥藍藻奶油起士餅乾(330g/包)</b>
#  <b class="OriginalPrice ng-binding">原價$99</b>
#  <b class="OnSalePrice">網路價$<b class="SaleNum ng-binding">88</b></b>
#  <!-- ngIf: item.TempLayer == 3 || item.TempLayer == null -->
#  <!-- ngIf: item.TempLayer == 1 --><b class="ProductLabel ng-scope" ng-if="item.TempLayer == 1"><img src="/img/t2.png" title="此為常溫商品，滿490元免運費，中午前訂購隔日送達。"/></b><!-- end ngIf: item.TempLayer == 1 -->
#  <!-- ngIf: item.TempLayer == 2 -->
#  <!-- ngIf: item.TempLayer == 4 -->
#  </a>,
#  <a class="ng-scope" href="javascript:void(0)" ng-if="item.ProductSalesQty &gt; 0"><b class="buy-botton" ng-click="AddCart(item)"><div id="buy-s"></div></b></a>,
#  <a href="/Branchs/Branch/Product/5/272/1271/7028">
#  <img ng-src="https://familycloud.blob.core.windows.net/products/10004342_1.jpg" src="https://familycloud.blob.core.windows.net/products/10004342_1.jpg"/>
#  <b class="special ng-binding"> </b>
#  <b class="Name ng-binding">中祥<br/>自然の顏量販包-紫菜蘇打(310g/包)</b>
#  <b class="OriginalPrice ng-binding">原價$99</b>
#  <b class="OnSalePrice">網路價$<b class="SaleNum ng-binding">88</b></b>
#  <!-- ngIf: item.TempLayer == 3 || item.TempLayer == null -->
#  <!-- ngIf: item.TempLayer == 1 --><b class="ProductLabel ng-scope" ng-if="item.TempLayer == 1"><img src="/img/t2.png" title="此為常溫商品，滿490元免運費，中午前訂購隔日送達。"/></b><!-- end ngIf: item.TempLayer == 1 -->
#  <!-- ngIf: item.TempLayer == 2 -->
#  <!-- ngIf: item.TempLayer == 4 -->
#  </a>,
#  <a class="ng-scope" href="javascript:void(0)" ng-if="item.ProductSalesQty &gt; 0"><b class="buy-botton" ng-click="AddCart(item)"><div id="buy-s"></div></b></a>,
#  <a href="/Branchs/Branch/Product/5/272/1271/7027">
#  <img ng-src="https://familycloud.blob.core.windows.net/products/10004341_1.jpg" src="https://familycloud.blob.core.windows.net/products/10004341_1.jpg"/>
#  <b class="special ng-binding"> </b>
#  <b class="Name ng-binding">中祥<br/>自然の顏量販包-蔬菜蘇打(360g/包)</b>
#  <b class="OriginalPrice ng-binding">原價$99</b>
#  <b class="OnSalePrice">網路價$<b class="SaleNum ng-binding">88</b></b>
#  <!-- ngIf: item.TempLayer == 3 || item.TempLayer == null -->
#  <!-- ngIf: item.TempLayer == 1 --><b class="ProductLabel ng-scope" ng-if="item.TempLayer == 1"><img src="/img/t2.png" title="此為常溫商品，滿490元免運費，中午前訂購隔日送達。"/></b><!-- end ngIf: item.TempLayer == 1 -->
#  <!-- ngIf: item.TempLayer == 2 -->
#  <!-- ngIf: item.TempLayer == 4 -->
#  </a>,
#  <a class="ng-scope" href="javascript:void(0)" ng-if="item.ProductSalesQty &gt; 0"><b class="buy-botton" ng-click="AddCart(item)"><div id="buy-s"></div></b></a>,
#  <a href="/Branchs/Branch/Product/5/272/1271/7026">
#  <img ng-src="https://familycloud.blob.core.windows.net/products/10004340_1.jpg" src="https://familycloud.blob.core.windows.net/products/10004340_1.jpg"/>
#  <b class="special ng-binding"> </b>
#  <b class="Name ng-binding">中祥<br/>自然の顏量販包-鮮奶油起士(360g/包)</b>
#  <b class="OriginalPrice ng-binding">原價$99</b>
#  <b class="OnSalePrice">網路價$<b class="SaleNum ng-binding">88</b></b>
#  <!-- ngIf: item.TempLayer == 3 || item.TempLayer == null -->
#  <!-- ngIf: item.TempLayer == 1 --><b class="ProductLabel ng-scope" ng-if="item.TempLayer == 1"><img src="/img/t2.png" title="此為常溫商品，滿490元免運費，中午前訂購隔日送達。"/></b><!-- end ngIf: item.TempLayer == 1 -->
#  <!-- ngIf: item.TempLayer == 2 -->
#  <!-- ngIf: item.TempLayer == 4 -->
#  </a>,
#  <a class="ng-scope" href="javascript:void(0)" ng-if="item.ProductSalesQty &gt; 0"><b class="buy-botton" ng-click="AddCart(item)"><div id="buy-s"></div></b></a>,
#  <a href="/Branchs/Branch/Product/5/272/1271/7025">
#  <img ng-src="https://familycloud.blob.core.windows.net/products/10004339_1.jpg" src="https://familycloud.blob.core.windows.net/products/10004339_1.jpg"/>
#  <b class="special ng-binding"> </b>
#  <b class="Name ng-binding">中祥<br/>自然の顏蔬菜蘇打(140g/包)</b>
#  <b class="OriginalPrice ng-binding">原價$45</b>
#  <b class="OnSalePrice">網路價$<b class="SaleNum ng-binding">40</b></b>
#  <!-- ngIf: item.TempLayer == 3 || item.TempLayer == null -->
#  <!-- ngIf: item.TempLayer == 1 --><b class="ProductLabel ng-scope" ng-if="item.TempLayer == 1"><img src="/img/t2.png" title="此為常溫商品，滿490元免運費，中午前訂購隔日送達。"/></b><!-- end ngIf: item.TempLayer == 1 -->
#  <!-- ngIf: item.TempLayer == 2 -->
#  <!-- ngIf: item.TempLayer == 4 -->
#  </a>,
#  <a class="ng-scope" href="javascript:void(0)" ng-if="item.ProductSalesQty &gt; 0"><b class="buy-botton" ng-click="AddCart(item)"><div id="buy-s"></div></b></a>,
#  <a href="/Branchs/Branch/Product/5/272/1271/7024">
#  <img ng-src="https://familycloud.blob.core.windows.net/products/10004338_1.jpg" src="https://familycloud.blob.core.windows.net/products/10004338_1.jpg"/>
#  <b class="special ng-binding"> </b>
#  <b class="Name ng-binding">中祥<br/>自然の顏紫菜蘇打(140g/包)</b>
#  <b class="OriginalPrice ng-binding">原價$45</b>
#  <b class="OnSalePrice">網路價$<b class="SaleNum ng-binding">40</b></b>
#  <!-- ngIf: item.TempLayer == 3 || item.TempLayer == null -->
#  <!-- ngIf: item.TempLayer == 1 --><b class="ProductLabel ng-scope" ng-if="item.TempLayer == 1"><img src="/img/t2.png" title="此為常溫商品，滿490元免運費，中午前訂購隔日送達。"/></b><!-- end ngIf: item.TempLayer == 1 -->
#  <!-- ngIf: item.TempLayer == 2 -->
#  <!-- ngIf: item.TempLayer == 4 -->
#  </a>,
#  <a class="ng-scope" href="javascript:void(0)" ng-if="item.ProductSalesQty &gt; 0"><b class="buy-botton" ng-click="AddCart(item)"><div id="buy-s"></div></b></a>]

# %%
a_href_list = soup.select('#SmallMedium > a')

# %%
for a_href in a_href_list:    
    a_href.select('.ng-scope')

# %%
a_href_list[1]
# Out:
# <a class="ng-scope" href="javascript:void(0)" ng-if="item.ProductSalesQty &gt; 0"><b class="buy-botton" ng-click="AddCart(item)"><div id="buy-s"></div></b></a>

# %%
for a_href in a_href_list:
    if a_href['href'] != 'javascript:void(0)':
        url = a_href['href']
        print(url)
# Out:
# /Branchs/Branch/Product/312/548/549/838
# /Branchs/Branch/Product/312/548/549/3901
# /Branchs/Branch/Product/312/548/549/3962
# /Branchs/Branch/Product/312/548/549/4208
# /Branchs/Branch/Product/312/548/549/3895
# /Branchs/Branch/Product/312/548/549/3961
# /Branchs/Branch/Product/312/548/549/4209
# /Branchs/Branch/Product/312/548/549/4207

# %% [markdown]
# ## 在此謝謝漢賢的技術支援，讓我知道要用PhantomJS

# %% [markdown]
# ### 看來中層爬蟲是邏輯上是沒問題了

# %% [markdown]
# # 下層爬蟲

# %%
def product_page_crawler(product_url):
    res = rq.get(product_url)
    soup = bs(res.text, 'lxml')
    
    product_dict = od()
    food_info_dict = od()  
    
    food_name = ''
    
    #找到最後一個有strong標籤的div，就會是內容
    div_index_needed = 0
    for div_index in range(1, 70):
        if hasattr(soup.select("div")[div_index].strong, 'text'):
            if div_index > div_index_needed:
                div_index_needed = div_index
            #print(div_index_needed)
    #print(div_index_needed)
    
    try:
        soup.select("div")[div_index_needed].strong.text
        content = soup.select("div")[div_index_needed]
        new_content = content
        
        while(new_content.strong != None):
            
            try:
                food_name += new_content.strong.text
                new_content.strong.extract()
                
            except AttributeError:
                break
                
        food_info_dict["food_name"] = food_name
        #print(food_info_dict)
        
    #------以下應該都沒用了-----
    except AttributeError:
        soup.select("div")[54].strong.text
        content = soup.select("div")[54]
        new_content = content
        
        while(new_content.strong != None):
            
            try:   
                food_name += new_content.strong.text
                new_content.strong.extract()
                
            except AttributeError:
                break
                
        food_info_dict["food_name"] = food_name
    #------以上應該都沒用了-----    
    
    except:
        print("[***ERROR***]can not find food_name!")
        
    while(True):
        
        try:
            new_content.br.replace_with(' ')
            
        except AttributeError:
            break
   
    food_info_and_other = new_content.text.strip().split() 
    
    #original_price
    food_info_dict["original_price"] = soup.select(".BOriginalPrice")[0].text
    #discount_price
    food_info_dict["discount_price"] = soup.select(".OnSalePrice > b")[0].text
    #stored_method
    food_info_dict["stored_method"] = soup.select(".BProductLabel")[0].img['alt']
    #category
    category_list = []
    a_hrefs = soup.select('#map-list')[0]
    branch_levels = a_hrefs.select('a')
    for branch in branch_levels:
        if(branch.text != '首頁'):
            category_list.append(branch.text)
    food_info_dict["category"] = category_list
    #weight
    food_info_dict["weight"] = food_info_and_other[1]
    #expired_date
    food_info_dict["expired_date"] = food_info_and_other[7]
    #country_of_origin
    food_info_dict["country_of_origin"] = food_info_and_other[5]
    
    #把food_info字典放入product_dict字典
    product_dict["food_info"] = food_info_dict
    
    #steps(未完成)
    #product_dict["steps"] = null
    
    #product_img_url
    product_dict["product_img_url"] = soup.select(".product_img_box")[0].img['src']
    #product_characteristic_img_url
    
    try:
        #不在P標籤內
        product_dict["product_characteristic_img_url"] = soup.select('div > img')[1]['src']
        #rint(product_dict)
        
    except IndexError:
        #在P標籤內
        product_dict["product_characteristic_img_url"] = soup.select("div > p > img")[0]['src']
    
    #web_url
    product_dict["web_url"] = product_url
    
    print(product_dict)

# %% [markdown]
# # 多頁測試

# %%
product_url_list = [
    'https://www.famicloud.com.tw/Branchs/Branch/Product/3/13/50/3872',
    'https://www.famicloud.com.tw/Branchs/Branch/Product/312/504/505/1170',
    'https://www.famicloud.com.tw/Branchs/Branch/Product/3/14/59/1288',
    'https://www.famicloud.com.tw/Branchs/Branch/Product/2/10/42/6012',
    'https://www.famicloud.com.tw/Branchs/Branch/Product/2/12/49/4258',
    'https://www.famicloud.com.tw/Branchs/Branch/Product/622/745/758/4118',
    'https://www.famicloud.com.tw/Branchs/Branch/Product/622/1278/1279/6289',
    'https://www.famicloud.com.tw/Branchs/Branch/Product/5/233/903/5056',
    'https://www.famicloud.com.tw/Branchs/Branch/Product/4/1055/1056/5286',
    'https://www.famicloud.com.tw/Branchs/Branch/Product/5/1023/1070/7001',
    'https://www.famicloud.com.tw/Branchs/Branch/Product/254/344/614/6688',
    'https://www.famicloud.com.tw/Branchs/Branch/Product/879/1016/1017/6361',
    'https://www.famicloud.com.tw/Branchs/Branch/Product/948/967/968/6951'
]

# %%
for product_url in product_url_list:
    product_page_crawler(product_url)
# Out:
# OrderedDict([('food_info', OrderedDict([('food_name', '家香豬五花火鍋肉片'), ('original_price', '原價$168'), ('discount_price', '145'), ('stored_method', '冷凍'), ('category', ['肉品肉類', '豬肉', '肉片\\肉條']), ('weight', '300g±5%/包'), ('expired_date', '180天'), ('country_of_origin', '台灣')])), ('product_img_url', 'https://familycloud.blob.core.windows.net/products/10001653_0.jpg'), ('product_characteristic_img_url', 'https://familycloud.blob.core.windows.net/products/3872/1653-2NEW2.jpg'), ('web_url', 'https://www.famicloud.com.tw/Branchs/Branch/Product/3/13/50/3872')])
# OrderedDict([('food_info', OrderedDict([('food_name', '築地一番鮮1855濕式熟成美國安格斯PRIME厚切沙朗牛排'), ('original_price', '原價$600'), ('discount_price', '359'), ('stored_method', '冷凍'), ('category', ['鮮食家推薦', '露營方便吃', '野炊生鮮']), ('weight', '500±30g/片'), ('expired_date', '365天'), ('country_of_origin', '美國')])), ('product_img_url', 'https://familycloud.blob.core.windows.net/products/10000378_0.jpg'), ('product_characteristic_img_url', 'https://familycloud.blob.core.windows.net/brands/10771580_Brand_01.jpg'), ('web_url', 'https://www.famicloud.com.tw/Branchs/Branch/Product/312/504/505/1170')])
# OrderedDict([('food_info', OrderedDict([('food_name', '御牧牛。產銷履歷牛腱'), ('original_price', '原價$630'), ('discount_price', '565'), ('stored_method', '冷凍'), ('category', ['肉品肉類', '牛肉', '紐約客\\板腱肉']), ('weight', '600g/包'), ('expired_date', '180天'), ('country_of_origin', '台灣')])), ('product_img_url', 'https://familycloud.blob.core.windows.net/products/10000496_0.jpg'), ('product_characteristic_img_url', 'https://familycloud.blob.core.windows.net/products/1288/0496-2.jpg'), ('web_url', 'https://www.famicloud.com.tw/Branchs/Branch/Product/3/14/59/1288')])
# OrderedDict([('food_info', OrderedDict([('food_name', '鮮之流。北太平洋半殼鮑魚'), ('original_price', '原價$536'), ('discount_price', '375'), ('stored_method', '冷凍'), ('category', ['生猛海鮮', '蝦\\蟹\\貝類', '鮑魚']), ('weight', '內容物:鮑魚'), ('expired_date', '食品業登錄字號:'), ('country_of_origin', '保存方式:')])), ('product_img_url', 'https://familycloud.blob.core.windows.net/products/10003419_0.jpg'), ('product_characteristic_img_url', 'https://familycloud.blob.core.windows.net/products/6012/3419-2.jpg'), ('web_url', 'https://www.famicloud.com.tw/Branchs/Branch/Product/2/10/42/6012')])
# OrderedDict([('food_info', OrderedDict([('food_name', '淳鮮健康海木耳(冷凍)'), ('original_price', '原價$90'), ('discount_price', '80'), ('stored_method', '冷凍'), ('category', ['生猛海鮮', '海菜類', '其他海菜']), ('weight', '100g/包'), ('expired_date', '180天'), ('country_of_origin', '台灣')])), ('product_img_url', 'https://familycloud.blob.core.windows.net/products/10001994_0.jpg'), ('product_characteristic_img_url', 'https://familycloud.blob.core.windows.net/products/4258/1994-2.jpg'), ('web_url', 'https://www.famicloud.com.tw/Branchs/Branch/Product/2/12/49/4258')])
# OrderedDict([('food_info', OrderedDict([('food_name', '天和鮮物海藻雞蒜頭雞湯'), ('original_price', '原價$240'), ('discount_price', '120'), ('stored_method', '冷凍'), ('category', ['天然有機', '天和鮮物', '調理即食']), ('weight', '480g±5%/包'), ('expired_date', '365天'), ('country_of_origin', '台灣')])), ('product_img_url', 'https://familycloud.blob.core.windows.net/products/10001886_0.jpg'), ('product_characteristic_img_url', 'https://familycloud.blob.core.windows.net/products/4118/1886-2.jpg'), ('web_url', 'https://www.famicloud.com.tw/Branchs/Branch/Product/622/745/758/4118')])
# OrderedDict([('food_info', OrderedDict([('food_name', '大漢酵素。有機酵素黑木耳露(黑糖)'), ('original_price', '原價$1080'), ('discount_price', '999'), ('stored_method', '常溫'), ('category', ['天然有機', '大漢酵素', '養生飲品']), ('weight', '350ml*24入/箱'), ('expired_date', '540天'), ('country_of_origin', '台灣')])), ('product_img_url', 'https://familycloud.blob.core.windows.net/products/10003690_0.jpg'), ('product_characteristic_img_url', 'https://familycloud.blob.core.windows.net/products/6289/3690-2.jpg'), ('web_url', 'https://www.famicloud.com.tw/Branchs/Branch/Product/622/1278/1279/6289')])
# OrderedDict([('food_info', OrderedDict([('food_name', 'Natural Benefits 純在。冷壓鮮榨。果汁6件組'), ('original_price', '原價$550'), ('discount_price', '438'), ('stored_method', '免運'), ('category', ['點心冰品', '沖泡飲品\\果汁', '果汁']), ('weight', '235毫升/瓶(鳳梨3瓶、甜菜根3瓶)'), ('expired_date', '10天'), ('country_of_origin', '台灣')])), ('product_img_url', 'https://familycloud.blob.core.windows.net/products/10002545_0.jpg'), ('product_characteristic_img_url', 'https://familycloud.blob.core.windows.net/products/5056/2545-2-NEW.jpg'), ('web_url', 'https://www.famicloud.com.tw/Branchs/Branch/Product/5/233/903/5056')])
# OrderedDict([('food_info', OrderedDict([('food_name', '樂淘小舖。毛小孩-羊肉牛蒡糙米飯'), ('original_price', '原價$98'), ('discount_price', '98'), ('stored_method', '冷凍'), ('category', ['調理即食', '寵物食品', '寵物鮮食']), ('weight', '150g±10g/包'), ('expired_date', '180天'), ('country_of_origin', '台灣')])), ('product_img_url', 'https://familycloud.blob.core.windows.net/products/10002741_0.jpg'), ('product_characteristic_img_url', 'https://familycloud.blob.core.windows.net/products/5286/2741-2.jpg'), ('web_url', 'https://www.famicloud.com.tw/Branchs/Branch/Product/4/1055/1056/5286')])
# OrderedDict([('food_info', OrderedDict([('food_name', '同正。碳燻李'), ('original_price', '原價$39'), ('discount_price', '65'), ('stored_method', '常溫'), ('category', ['點心冰品', '休閒零食', '果乾/蜜餞']), ('weight', '90g/包'), ('expired_date', '360天'), ('country_of_origin', '台灣')])), ('product_img_url', 'https://familycloud.blob.core.windows.net/products/10004315_0.jpg'), ('product_characteristic_img_url', 'https://familycloud.blob.core.windows.net/products/7001/765.jpg'), ('web_url', 'https://www.famicloud.com.tw/Branchs/Branch/Product/5/1023/1070/7001')])
# OrderedDict([('food_info', OrderedDict([('food_name', '儒齋。玉米香排-奶蛋素'), ('original_price', '原價$156'), ('discount_price', '78'), ('stored_method', '冷凍'), ('category', ['素食蔬果', '素食料理', '家常菜']), ('weight', '內容物:水、組織大豆蛋白、非基改芥花油、新鮮雞蛋、蛋白粉、大豆分離蛋白、樹薯澱粉、小麥蛋白、玉米、紅蘿蔔、青豆仁、砂糖、鹽、L-麩酸鈉、酵母抽出物'), ('expired_date', '冷凍素食'), ('country_of_origin', '食用方式:主、排餐，西式菜')])), ('product_img_url', 'https://familycloud.blob.core.windows.net/products/10004059_0.jpg'), ('product_characteristic_img_url', 'https://familycloud.blob.core.windows.net/products/6688/4059-2.jpg'), ('web_url', 'https://www.famicloud.com.tw/Branchs/Branch/Product/254/344/614/6688')])
# OrderedDict([('food_info', OrderedDict([('food_name', '台糖。頂級橄欖油'), ('original_price', '原價$360'), ('discount_price', '145'), ('stored_method', '常溫'), ('category', ['調味醬料', '料理油', '食用油']), ('weight', '750ml/瓶'), ('expired_date', '產地:'), ('country_of_origin', 'Virgin頂級')])), ('product_img_url', 'https://familycloud.blob.core.windows.net/products/10003762_0.jpg'), ('product_characteristic_img_url', 'https://familycloud.blob.core.windows.net/products/6361/3762-2.jpg'), ('web_url', 'https://www.famicloud.com.tw/Branchs/Branch/Product/879/1016/1017/6361')])
# OrderedDict([('food_info', OrderedDict([('food_name', '頂級乾燥。TOPDRY黑糖老薑'), ('original_price', '原價$124'), ('discount_price', '179'), ('stored_method', '常溫'), ('category', ['490免運區', '沖泡飲品\\果汁', '養生飲品']), ('weight', '內容物:黑糖、糖蜜、老薑、食鹽'), ('expired_date', '注意事項:請置於陰涼乾燥處，避免陽光直射'), ('country_of_origin', '保存方式:')])), ('product_img_url', 'https://familycloud.blob.core.windows.net/products/10004269_0.jpg'), ('product_characteristic_img_url', 'https://familycloud.blob.core.windows.net/products/6951/4269-2.jpg'), ('web_url', 'https://www.famicloud.com.tw/Branchs/Branch/Product/948/967/968/6951')])
